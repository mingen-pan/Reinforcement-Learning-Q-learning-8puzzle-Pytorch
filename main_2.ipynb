# %%
from n_puzzle import N_puzzle
from DQN import hidden_unit, Q_learning, RL_training

# %%
network = Q_learning(72, [250,250], 4, hidden_unit)
train = RL_training(3, 10, network, epsilon = 0.9, gamma = 0.9, lr = 1e-4)
train.train(10001,1000)
train.test()
train.optimizer.param_groups[0]['lr'] = 5e-5
train.epsilon = 0.5
train.train(10001,1000)
train.test()
train.optimizer.param_groups[0]['lr'] = 1e-5
train.epsilon = 0.5
train.train(10001,1000)
train.test()
train.optimizer.param_groups[0]['lr'] = 5e-6
train.epsilon = 0.5
train.train(10001,1000)
train.test()
# Out:
# epoch is 0
# epsilon is 0.90
# success rate: 0.00
#
#
# epoch is 1000
# epsilon is 0.80
# success rate: 0.00
# 20 steps are trained and stop
#
#
# epoch is 2000
# epsilon is 0.70
# success rate: 0.00
# 20 steps are trained and stop
#
#
# epoch is 3000
# epsilon is 0.60
# success rate: 0.70
# 20 steps are trained and stop
#
#
# epoch is 4000
# epsilon is 0.50
# success rate: 4.70
# 20 steps are trained and stop
#
#
# epoch is 5000
# epsilon is 0.40
# success rate: 18.60
# 19 steps are trained and the reward is 10
#
#
# epoch is 6000
# epsilon is 0.30
# success rate: 39.40
# 17 steps are trained and the reward is 10
#
#
# epoch is 7000
# epsilon is 0.20
# success rate: 56.60
# 20 steps are trained and stop
#
#
# epoch is 8000
# epsilon is 0.10
# success rate: 70.30
# 15 steps are trained and the reward is 10
#
#
# epoch is 9000
# epsilon is 0.10
# success rate: 72.30
# 10 steps are trained and the reward is 10
#
#
# epoch is 10000
# epsilon is 0.10
# success rate: 75.80
# 14 steps are trained and the reward is 10
# Initial State:
#
#  0  1  2
#  7  4  3
#  8  6  5
# [torch.IntTensor of size 3x3]
#
#
# -47.7360 -43.6246 -47.3645 -33.8891
# [torch.FloatTensor of size 1x4]
#
# distance:  10
# Move #: 0; Taking action: 3
#
#  1  0  2
#  7  4  3
#  8  6  5
# [torch.IntTensor of size 3x3]
#
#
# -37.0917 -35.8965 -37.9613 -27.3964
# [torch.FloatTensor of size 1x4]
#
# distance:  9
# Move #: 1; Taking action: 3
#
#  1  2  0
#  7  4  3
#  8  6  5
# [torch.IntTensor of size 3x3]
#
#
# -17.8093 -27.1354 -26.5603 -29.1659
# [torch.FloatTensor of size 1x4]
#
# distance:  8
# Move #: 2; Taking action: 0
#
#  1  2  3
#  7  4  0
#  8  6  5
# [torch.IntTensor of size 3x3]
#
#
# -12.1851 -21.0697 -19.8927 -26.4680
# [torch.FloatTensor of size 1x4]
#
# distance:  7
# Move #: 3; Taking action: 0
#
#  1  2  3
#  7  4  5
#  8  6  0
# [torch.IntTensor of size 3x3]
#
#
# -17.3648 -21.3221  -7.7137 -23.0107
# [torch.FloatTensor of size 1x4]
#
# distance:  6
# Move #: 4; Taking action: 2
#
#  1  2  3
#  7  4  5
#  8  0  6
# [torch.IntTensor of size 3x3]
#
#
#  -9.3398 -11.0863  -3.5684 -13.0456
# [torch.FloatTensor of size 1x4]
#
# distance:  5
# Move #: 5; Taking action: 2
#
#  1  2  3
#  7  4  5
#  0  8  6
# [torch.IntTensor of size 3x3]
#
#
#  -6.8446   0.1904  -4.2657 -10.1648
# [torch.FloatTensor of size 1x4]
#
# distance:  4
# Move #: 6; Taking action: 1
#
#  1  2  3
#  0  4  5
#  7  8  6
# [torch.IntTensor of size 3x3]
#
#
# -0.5529  0.9156  0.4083  3.9554
# [torch.FloatTensor of size 1x4]
#
# distance:  3
# Move #: 7; Taking action: 3
#
#  1  2  3
#  4  0  5
#  7  8  6
# [torch.IntTensor of size 3x3]
#
#
#  0.9482  0.6826  1.5910  7.0970
# [torch.FloatTensor of size 1x4]
#
# distance:  2
# Move #: 8; Taking action: 3
#
#  1  2  3
#  4  5  0
#  7  8  6
# [torch.IntTensor of size 3x3]
#
#
#  9.4575  3.8667  3.9379  5.6990
# [torch.FloatTensor of size 1x4]
#
# distance:  1
# Move #: 9; Taking action: 0
#
#  1  2  3
#  4  5  6
#  7  8  0
# [torch.IntTensor of size 3x3]
#
# Reward: 10
#
#
# epoch is 0
# epsilon is 0.50
# success rate: 0.00
# 20 steps are trained and stop
#
#
# epoch is 1000
# epsilon is 0.40
# success rate: 35.00
# 18 steps are trained and the reward is 10
#
#
# epoch is 2000
# epsilon is 0.30
# success rate: 54.00
# 20 steps are trained and stop
#
#
# epoch is 3000
# epsilon is 0.20
# success rate: 66.60
# 14 steps are trained and the reward is 10
#
#
# epoch is 4000
# epsilon is 0.10
# success rate: 78.40
# 20 steps are trained and stop
#
#
# epoch is 5000
# epsilon is 0.10
# success rate: 79.50
# 10 steps are trained and the reward is 10
#
#
# epoch is 6000
# epsilon is 0.10
# success rate: 77.90
# 10 steps are trained and the reward is 10
#
#
# epoch is 7000
# epsilon is 0.10
# success rate: 77.00
# 20 steps are trained and stop
#
#
# epoch is 8000
# epsilon is 0.10
# success rate: 78.40
# 11 steps are trained and the reward is 10
#
#
# epoch is 9000
# epsilon is 0.10
# success rate: 79.70
# 16 steps are trained and the reward is 10
#
#
# epoch is 10000
# epsilon is 0.10
# success rate: 78.40
# 10 steps are trained and the reward is 10
# Initial State:
#
#  1  6  2
#  7  0  3
#  5  4  8
# [torch.IntTensor of size 3x3]
#
#
# -34.7979 -33.2074 -51.6755 -48.3486
# [torch.FloatTensor of size 1x4]
#
# distance:  10
# Move #: 0; Taking action: 1
#
#  1  0  2
#  7  6  3
#  5  4  8
# [torch.IntTensor of size 3x3]
#
#
# -32.2196 -37.3038 -36.5111 -26.8061
# [torch.FloatTensor of size 1x4]
#
# distance:  9
# Move #: 1; Taking action: 3
#
#  1  2  0
#  7  6  3
#  5  4  8
# [torch.IntTensor of size 3x3]
#
#
# -20.1160 -35.7499 -36.6383 -35.6428
# [torch.FloatTensor of size 1x4]
#
# distance:  8
# Move #: 2; Taking action: 0
#
#  1  2  3
#  7  6  0
#  5  4  8
# [torch.IntTensor of size 3x3]
#
#
# -25.7589 -25.0553 -13.6198 -20.6495
# [torch.FloatTensor of size 1x4]
#
# distance:  7
# Move #: 3; Taking action: 2
#
#  1  2  3
#  7  0  6
#  5  4  8
# [torch.IntTensor of size 3x3]
#
#
#  -7.6152 -18.6289 -18.2720 -14.7019
# [torch.FloatTensor of size 1x4]
#
# distance:  6
# Move #: 4; Taking action: 0
#
#  1  2  3
#  7  4  6
#  5  0  8
# [torch.IntTensor of size 3x3]
#
#
# -7.8018 -7.8231 -2.3995 -7.4025
# [torch.FloatTensor of size 1x4]
#
# distance:  5
# Move #: 5; Taking action: 2
#
#  1  2  3
#  7  4  6
#  0  5  8
# [torch.IntTensor of size 3x3]
#
#
# -4.6303  2.1153 -5.4585 -7.1374
# [torch.FloatTensor of size 1x4]
#
# distance:  4
# Move #: 6; Taking action: 1
#
#  1  2  3
#  0  4  6
#  7  5  8
# [torch.IntTensor of size 3x3]
#
#
# -2.5163 -0.8835 -0.3863  5.0409
# [torch.FloatTensor of size 1x4]
#
# distance:  3
# Move #: 7; Taking action: 3
#
#  1  2  3
#  4  0  6
#  7  5  8
# [torch.IntTensor of size 3x3]
#
#
#  8.4668  2.9343  4.2052  3.2150
# [torch.FloatTensor of size 1x4]
#
# distance:  2
# Move #: 8; Taking action: 0
#
#  1  2  3
#  4  5  6
#  7  0  8
# [torch.IntTensor of size 3x3]
#
#
#   5.6550   7.2571   6.1867  10.0511
# [torch.FloatTensor of size 1x4]
#
# distance:  1
# Move #: 9; Taking action: 3
#
#  1  2  3
#  4  5  6
#  7  8  0
# [torch.IntTensor of size 3x3]
#
# Reward: 10
#
#
# epoch is 0
# epsilon is 0.50
# success rate: 0.00
# 14 steps are trained and the reward is 10
#
#
# epoch is 1000
# epsilon is 0.40
# success rate: 38.50
# 20 steps are trained and stop
#
#
# epoch is 2000
# epsilon is 0.30
# success rate: 54.80
# 14 steps are trained and the reward is 10
#
#
# epoch is 3000
# epsilon is 0.20
# success rate: 71.00
# 16 steps are trained and the reward is 10
#
#
# epoch is 4000
# epsilon is 0.10
# success rate: 79.90
# 20 steps are trained and stop
#
#
# epoch is 5000
# epsilon is 0.10
# success rate: 78.30
# 20 steps are trained and stop
#
#
# epoch is 6000
# epsilon is 0.10
# success rate: 78.00
# 13 steps are trained and the reward is 10
#
#
# epoch is 7000
# epsilon is 0.10
# success rate: 80.70
# 16 steps are trained and the reward is 10
#
#
# epoch is 8000
# epsilon is 0.10
# success rate: 82.00
# 10 steps are trained and the reward is 10
#
#
# epoch is 9000
# epsilon is 0.10
# success rate: 83.50
# 20 steps are trained and stop
#
#
# epoch is 10000
# epsilon is 0.10
# success rate: 82.80
# 10 steps are trained and the reward is 10
# Initial State:
#
#  2  7  3
#  1  0  5
#  8  4  6
# [torch.IntTensor of size 3x3]
#
#
# -38.6590 -30.8088 -42.8321 -42.8125
# [torch.FloatTensor of size 1x4]
#
# distance:  10
# Move #: 0; Taking action: 1
#
#  2  0  3
#  1  7  5
#  8  4  6
# [torch.IntTensor of size 3x3]
#
#
# -36.9774 -35.6013 -24.1346 -34.0569
# [torch.FloatTensor of size 1x4]
#
# distance:  9
# Move #: 1; Taking action: 2
#
#  0  2  3
#  1  7  5
#  8  4  6
# [torch.IntTensor of size 3x3]
#
#
# -18.1854 -25.7558 -25.3019 -29.0509
# [torch.FloatTensor of size 1x4]
#
# distance:  8
# Move #: 2; Taking action: 0
#
#  1  2  3
#  0  7  5
#  8  4  6
# [torch.IntTensor of size 3x3]
#
#
# -16.7247 -18.5423 -17.6062 -11.9768
# [torch.FloatTensor of size 1x4]
#
# distance:  7
# Move #: 3; Taking action: 3
#
#  1  2  3
#  7  0  5
#  8  4  6
# [torch.IntTensor of size 3x3]
#
#
#  -6.6302 -18.1767 -19.2399 -19.9179
# [torch.FloatTensor of size 1x4]
#
# distance:  6
# Move #: 4; Taking action: 0
#
#  1  2  3
#  7  4  5
#  8  0  6
# [torch.IntTensor of size 3x3]
#
#
# -12.1420 -13.4849  -1.7883 -12.1426
# [torch.FloatTensor of size 1x4]
#
# distance:  5
# Move #: 5; Taking action: 2
#
#  1  2  3
#  7  4  5
#  0  8  6
# [torch.IntTensor of size 3x3]
#
#
# -2.9066  2.3597 -3.9098 -5.8946
# [torch.FloatTensor of size 1x4]
#
# distance:  4
# Move #: 6; Taking action: 1
#
#  1  2  3
#  0  4  5
#  7  8  6
# [torch.IntTensor of size 3x3]
#
#
# -1.2350 -0.8303  0.1540  5.3528
# [torch.FloatTensor of size 1x4]
#
# distance:  3
# Move #: 7; Taking action: 3
#
#  1  2  3
#  4  0  5
#  7  8  6
# [torch.IntTensor of size 3x3]
#
#
#  1.5770  1.5613  1.2429  7.9030
# [torch.FloatTensor of size 1x4]
#
# distance:  2
# Move #: 8; Taking action: 3
#
#  1  2  3
#  4  5  0
#  7  8  6
# [torch.IntTensor of size 3x3]
#
#
#  10.0004   7.0840   6.3490   8.1254
# [torch.FloatTensor of size 1x4]
#
# distance:  1
# Move #: 9; Taking action: 0
#
#  1  2  3
#  4  5  6
#  7  8  0
# [torch.IntTensor of size 3x3]
#
# Reward: 10
#
#
# epoch is 0
# epsilon is 0.50
# success rate: 0.00
# 20 steps are trained and stop
# epoch is 1000
# epsilon is 0.40
# success rate: 37.70
# 16 steps are trained and the reward is 10
#
#
# epoch is 2000
# epsilon is 0.30
# success rate: 56.90
# 18 steps are trained and the reward is 10
#
#
# epoch is 3000
# epsilon is 0.20
# success rate: 73.50
# 16 steps are trained and the reward is 10
#
#
# epoch is 4000
# epsilon is 0.10
# success rate: 79.90
# 10 steps are trained and the reward is 10
#
#
# epoch is 5000
# epsilon is 0.10
# success rate: 85.00
# 13 steps are trained and the reward is 10
#
#
# epoch is 6000
# epsilon is 0.10
# success rate: 82.10
# 10 steps are trained and the reward is 10
#
#
# epoch is 7000
# epsilon is 0.10
# success rate: 79.90
# 15 steps are trained and the reward is 10
#
#
# epoch is 8000
# epsilon is 0.10
# success rate: 81.10
# 20 steps are trained and stop
#
#
# epoch is 9000
# epsilon is 0.10
# success rate: 83.60
# 11 steps are trained and the reward is 10
#
#
# epoch is 10000
# epsilon is 0.10
# success rate: 82.00
# 11 steps are trained and the reward is 10
# Initial State:
#
#  0  2  3
#  1  4  7
#  5  6  8
# [torch.IntTensor of size 3x3]
#
#
# -70.1062 -80.7502 -81.3445 -80.8611
# [torch.FloatTensor of size 1x4]
#
# distance:  10
# Move #: 0; Taking action: 0
#
#  1  2  3
#  0  4  7
#  5  6  8
# [torch.IntTensor of size 3x3]
#
#
# -81.3428 -85.6477 -77.1228 -70.7927
# [torch.FloatTensor of size 1x4]
#
# distance:  9
# Move #: 1; Taking action: 3
#
#  1  2  3
#  4  0  7
#  5  6  8
# [torch.IntTensor of size 3x3]
#
#
# -94.2297 -99.7201 -93.8633 -85.1593
# [torch.FloatTensor of size 1x4]
#
# distance:  8
# Move #: 2; Taking action: 3
#
#  1  2  3
#  4  7  0
#  5  6  8
# [torch.IntTensor of size 3x3]
#
#
# -63.6843 -70.2552 -73.2070 -72.4663
# [torch.FloatTensor of size 1x4]
#
# distance:  7
# Move #: 3; Taking action: 0
#
#  1  2  3
#  4  7  8
#  5  6  0
# [torch.IntTensor of size 3x3]
#
#
# -66.1778 -59.3934 -64.9115 -66.6203
# [torch.FloatTensor of size 1x4]
#
# distance:  8
# Move #: 4; Taking action: 1
#
#  1  2  3
#  4  7  0
#  5  6  8
# [torch.IntTensor of size 3x3]
#
#
# -63.6843 -70.2552 -73.2070 -72.4663
# [torch.FloatTensor of size 1x4]
#
# distance:  7
# Move #: 5; Taking action: 0
#
#  1  2  3
#  4  7  8
#  5  6  0
# [torch.IntTensor of size 3x3]
#
#
# -66.1778 -59.3934 -64.9115 -66.6203
# [torch.FloatTensor of size 1x4]
#
# distance:  8
# Move #: 6; Taking action: 1
#
#  1  2  3
#  4  7  0
#  5  6  8
# [torch.IntTensor of size 3x3]
#
#
# -63.6843 -70.2552 -73.2070 -72.4663
# [torch.FloatTensor of size 1x4]
#
# distance:  7
# Move #: 7; Taking action: 0
#
#  1  2  3
#  4  7  8
#  5  6  0
# [torch.IntTensor of size 3x3]
#
#
# -66.1778 -59.3934 -64.9115 -66.6203
# [torch.FloatTensor of size 1x4]
#
# distance:  8
# Move #: 8; Taking action: 1
#
#  1  2  3
#  4  7  0
#  5  6  8
# [torch.IntTensor of size 3x3]
#
#
# -63.6843 -70.2552 -73.2070 -72.4663
# [torch.FloatTensor of size 1x4]
#
# distance:  7
# Move #: 9; Taking action: 0
#
#  1  2  3
#  4  7  8
#  5  6  0
# [torch.IntTensor of size 3x3]
#
#
# -66.1778 -59.3934 -64.9115 -66.6203
# [torch.FloatTensor of size 1x4]
#
# distance:  8
# Move #: 10; Taking action: 1
#
#  1  2  3
#  4  7  0
#  5  6  8
# [torch.IntTensor of size 3x3]
#
#
# -63.6843 -70.2552 -73.2070 -72.4663
# [torch.FloatTensor of size 1x4]
#
# distance:  7
# Move #: 11; Taking action: 0
#
#  1  2  3
#  4  7  8
#  5  6  0
# [torch.IntTensor of size 3x3]
#
#
# -66.1778 -59.3934 -64.9115 -66.6203
# [torch.FloatTensor of size 1x4]
#
# distance:  8
# Move #: 12; Taking action: 1
#
#  1  2  3
#  4  7  0
#  5  6  8
# [torch.IntTensor of size 3x3]
#
#
# -63.6843 -70.2552 -73.2070 -72.4663
# [torch.FloatTensor of size 1x4]
#
# distance:  7
# Move #: 13; Taking action: 0
#
#  1  2  3
#  4  7  8
#  5  6  0
# [torch.IntTensor of size 3x3]
#
#
# -66.1778 -59.3934 -64.9115 -66.6203
# [torch.FloatTensor of size 1x4]
#
# distance:  8
# Move #: 14; Taking action: 1
#
#  1  2  3
#  4  7  0
#  5  6  8
# [torch.IntTensor of size 3x3]
#
#
# -63.6843 -70.2552 -73.2070 -72.4663
# [torch.FloatTensor of size 1x4]
#
# distance:  7
# Move #: 15; Taking action: 0
#
#  1  2  3
#  4  7  8
#  5  6  0
# [torch.IntTensor of size 3x3]
#
# Game lost; too many moves.
